# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as pylab
from stimuli import Figure5

# %%
#There are lots of permutations and it would be repetitive to show all of them, so here's a rundown of the flags
#Flag 1 - True: Arranged in a diagonal, False: Y position is random
#Flag 2 - True: X position can "wiggle" (be up to 5 px off normal position), False: X position is constant
#Flag 3 - True: The largest stimulus is always at the farthest left position, False: the largest can be any of the 4

# %%
#Obviously flags 1 and 3 are irrelevant to the two position stimuli
pylab.imshow(Figure5.position_common_scale(flags=[False, False, True])[1])

# %%
pylab.imshow(Figure5.position_common_scale(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.position_non_aligned_scale(flags=[False, False, False])[1])

# %%
pylab.imshow(Figure5.position_non_aligned_scale(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.length(flags=[False, False, False])[1])

# %%
pylab.imshow(Figure5.length(flags=[True, False, False])[1])

# %%
pylab.imshow(Figure5.length(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.length(flags=[True, True, False])[1])

# %%
pylab.imshow(Figure5.length(flags=[True, False, True])[1])

# %%
pylab.imshow(Figure5.length(flags=[True, True, True])[1])

# %%
pylab.imshow(Figure5.angle(flags=[False, False, False])[1])

# %%
pylab.imshow(Figure5.angle(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.angle(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.angle(flags=[True, True, True])[1])

# %%
pylab.imshow(Figure5.angle(flags=[True, True, False])[1])

# %%
pylab.imshow(Figure5.direction(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.direction(flags=[False, False, False])[1])

# %%
pylab.imshow(Figure5.direction(flags=[True, False, True])[1])

# %%
pylab.imshow(Figure5.area(flags=[True, False, True])[1])

# %%
pylab.imshow(Figure5.area(flags=[True, True, True])[1])

# %%
pylab.imshow(Figure5.area(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.area(flags=[False, False, True])[1])

# %%
pylab.imshow(Figure5.area(flags=[False, False, False])[1])

# %%
pylab.imshow(Figure5.volume(flags=[True, False, True])[1])

# %%
pylab.imshow(Figure5.volume(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.volume(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.volume(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.volume(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.curvature(flags=[False, True, True])[1])

# %%
pylab.imshow(Figure5.curvature(flags=[False, True, False])[1])

# %%
pylab.imshow(Figure5.curvature(flags=[False, False, True])[1])

# %%
pylab.imshow(Figure5.curvature(flags=[True, True, False])[1])
