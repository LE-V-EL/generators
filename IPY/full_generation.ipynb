# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/jwfree/anaconda3/envs/generators/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import os
sys.path.append('..')
from dataset import DatasetGenerator, DatasetFromFile
import matplotlib.pyplot as pylab
import pprint
import numpy as np

# %%
data_class_list_1 = [
        'position_non_aligned_scale',
        'position_common_scale',
        'angle',
        'length',
        'direction',
        'curvature'
    ]

data_class_list_2 = [
        'area',
        'volume'
]

for data_class in data_class_list_1:
    dataset_generator = DatasetGenerator(
        data_class=data_class,
        counts={"train": 60000, "val": 20000, "test": 20000}
    )
    dataset_generator.generate()
    
for data_class in data_class_list_2:
    dataset_generator = DatasetGenerator(
        data_class=data_class,
        counts={"train": 6000, "val": 2000, "test": 2000}
    )
    dataset_generator.generate()
# Out:
# Generating dataset of class:  position_non_aligned_scale
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Accepted:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  6000
# Generation Loop Itteration:  7000
# Labels Accepted:  7000
# Generation Loop Itteration:  8000
# Labels Accepted:  8000
# Generation Loop Itteration:  9000
# Labels Accepted:  9000
# Generation Loop Itteration:  10000
# Labels Accepted:  10000
# Generation Loop Itteration:  11000
# Labels Accepted:  11000
# Generation Loop Itteration:  12000
# Labels Accepted:  12000
# Generation Loop Itteration:  13000
# Labels Accepted:  13000
# Generation Loop Itteration:  14000
# Labels Accepted:  14000
# Generation Loop Itteration:  15000
# Labels Accepted:  15000
# Generation Loop Itteration:  16000
# Labels Accepted:  16000
# Generation Loop Itteration:  17000
# Labels Accepted:  17000
# Generation Loop Itteration:  18000
# Labels Accepted:  18000
# Generation Loop Itteration:  19000
# Labels Accepted:  19000
# Generation Loop Itteration:  20000
# Labels Accepted:  20000
# Generation Loop Itteration:  21000
# Labels Accepted:  21000
# Generation Loop Itteration:  22000
# Generation Loop Itteration:  23000
# Labels Accepted:  22000
# Generation Loop Itteration:  24000
# Labels Accepted:  23000
# Generation Loop Itteration:  25000
# Labels Accepted:  24000
# Generation Loop Itteration:  26000
# Labels Accepted:  25000
# Generation Loop Itteration:  27000
# Labels Accepted:  26000
# Generation Loop Itteration:  28000
# Labels Accepted:  27000
# Generation Loop Itteration:  29000
# Labels Accepted:  28000
# Generation Loop Itteration:  30000
# Labels Accepted:  29000
# Generation Loop Itteration:  31000
# Labels Accepted:  30000
# Generation Loop Itteration:  32000
# Labels Accepted:  31000
# Generation Loop Itteration:  33000
# Labels Accepted:  32000
# Generation Loop Itteration:  34000
# Labels Accepted:  33000
# Generation Loop Itteration:  35000
# Labels Accepted:  34000
# Generation Loop Itteration:  36000
# Labels Accepted:  35000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  37000
# Labels Accepted:  36000
# Generation Loop Itteration:  38000
# Labels Accepted:  37000
# Generation Loop Itteration:  39000
# Labels Accepted:  38000
# Generation Loop Itteration:  40000
# Labels Accepted:  39000
# Generation Loop Itteration:  41000
# Labels Accepted:  40000
# Generation Loop Itteration:  42000
# Labels Accepted:  41000
# Generation Loop Itteration:  43000
# Generation Loop Itteration:  44000
# Labels Accepted:  42000
# Generation Loop Itteration:  45000
# Labels Accepted:  43000
# Generation Loop Itteration:  46000
# Labels Accepted:  44000
# Generation Loop Itteration:  47000
# Labels Accepted:  45000
# Generation Loop Itteration:  48000
# Labels Accepted:  46000
# Generation Loop Itteration:  49000
# Labels Accepted:  47000
# Generation Loop Itteration:  50000
# Labels Accepted:  48000
# Generation Loop Itteration:  51000
# Labels Accepted:  49000
# Generation Loop Itteration:  52000
# Labels Accepted:  50000
# Generation Loop Itteration:  53000
# Labels Rejected by Euclidian Distance:  2000
# Labels Accepted:  51000
# Generation Loop Itteration:  54000
# Labels Accepted:  52000
# Generation Loop Itteration:  55000
# Labels Accepted:  53000
# Generation Loop Itteration:  56000
# Labels Accepted:  54000
# Generation Loop Itteration:  57000
# Labels Accepted:  55000
# Generation Loop Itteration:  58000
# Generation Loop Itteration:  59000
# Labels Accepted:  56000
# Generation Loop Itteration:  60000
# Labels Accepted:  57000
# Generation Loop Itteration:  61000
# Labels Accepted:  58000
# Generation Loop Itteration:  62000
# Labels Accepted:  59000
# Generation Loop Itteration:  63000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  64000
# Labels Rejected by Uneven Label Distribution:  1000
# Generation Loop Itteration:  65000
# Labels Accepted:  61000
# Labels Rejected by Euclidian Distance:  3000
# Generation Loop Itteration:  66000
# Labels Accepted:  62000
# Generation Loop Itteration:  67000
# Labels Accepted:  63000
# Generation Loop Itteration:  68000
# Labels Accepted:  64000
# Generation Loop Itteration:  69000
# Labels Accepted:  65000
# Generation Loop Itteration:  70000
# Labels Accepted:  66000
# Generation Loop Itteration:  71000
# Labels Accepted:  67000
# Generation Loop Itteration:  72000
# Labels Accepted:  68000
# Generation Loop Itteration:  73000
# Generation Loop Itteration:  74000
# Labels Accepted:  69000
# Generation Loop Itteration:  75000
# Labels Accepted:  70000
# Generation Loop Itteration:  76000
# Labels Rejected by Euclidian Distance:  4000
# Labels Accepted:  71000
# Generation Loop Itteration:  77000
# Labels Accepted:  72000
# Generation Loop Itteration:  78000
# Labels Accepted:  73000
# Generation Loop Itteration:  79000
# Labels Accepted:  74000
# Generation Loop Itteration:  80000
# Labels Accepted:  75000
# Generation Loop Itteration:  81000
# Labels Accepted:  76000
# Generation Loop Itteration:  82000
# Labels Accepted:  77000
# Generation Loop Itteration:  83000
# Generation Loop Itteration:  84000
# Labels Accepted:  78000
# Generation Loop Itteration:  85000
# Labels Accepted:  79000
# Labels Rejected by Euclidian Distance:  5000
# Generation Loop Itteration:  86000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  87000
# Generation Loop Itteration:  88000
# Labels Accepted:  81000
# Generation Loop Itteration:  89000
# Labels Accepted:  82000
# Generation Loop Itteration:  90000
# Labels Accepted:  83000
# Generation Loop Itteration:  91000
# Labels Accepted:  84000
# Generation Loop Itteration:  92000
# Labels Accepted:  85000
# Generation Loop Itteration:  93000
# Labels Rejected by Euclidian Distance:  6000
# Labels Accepted:  86000
# Generation Loop Itteration:  94000
# Generation Loop Itteration:  95000
# Labels Accepted:  87000
# Generation Loop Itteration:  96000
# Labels Accepted:  88000
# Generation Loop Itteration:  97000
# Labels Accepted:  89000
# Generation Loop Itteration:  98000
# Labels Accepted:  90000
# Generation Loop Itteration:  99000
# Labels Accepted:  91000
# Generation Loop Itteration:  100000
# Labels Accepted:  92000
# Generation Loop Itteration:  101000
# Labels Accepted:  93000
# Generation Loop Itteration:  102000
# Labels Rejected by Euclidian Distance:  7000
# Generation Loop Itteration:  103000
# Labels Accepted:  94000
# Generation Loop Itteration:  104000
# Labels Accepted:  95000
# Generation Loop Itteration:  105000
# Labels Accepted:  96000
# Generation Loop Itteration:  106000
# Labels Accepted:  97000
# Generation Loop Itteration:  107000
# Labels Accepted:  98000
# Generation Loop Itteration:  108000
# Labels Accepted:  99000
# Generation Loop Itteration:  109000
# Labels Rejected by Euclidian Distance:  8000
# Generation Loop Itteration:  110000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:04:44.081222
# Generating dataset of class:  position_common_scale
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Accepted:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  6000
# Generation Loop Itteration:  7000
# Labels Accepted:  7000
# Generation Loop Itteration:  8000
# Labels Accepted:  8000
# Generation Loop Itteration:  9000
# Labels Accepted:  9000
# Generation Loop Itteration:  10000
# Labels Accepted:  10000
# Generation Loop Itteration:  11000
# Labels Accepted:  11000
# Generation Loop Itteration:  12000
# Labels Accepted:  12000
# Generation Loop Itteration:  13000
# Labels Accepted:  13000
# Generation Loop Itteration:  14000
# Labels Accepted:  14000
# Generation Loop Itteration:  15000
# Labels Accepted:  15000
# Generation Loop Itteration:  16000
# Labels Accepted:  16000
# Generation Loop Itteration:  17000
# Labels Accepted:  17000
# Generation Loop Itteration:  18000
# Labels Accepted:  18000
# Generation Loop Itteration:  19000
# Labels Accepted:  19000
# Generation Loop Itteration:  20000
# Labels Accepted:  20000
# Generation Loop Itteration:  21000
# Labels Accepted:  21000
# Generation Loop Itteration:  22000
# Labels Accepted:  22000
# Generation Loop Itteration:  23000
# Labels Accepted:  23000
# Generation Loop Itteration:  24000
# Labels Accepted:  24000
# Generation Loop Itteration:  25000
# Labels Accepted:  25000
# Generation Loop Itteration:  26000
# Labels Accepted:  26000
# Generation Loop Itteration:  27000
# Labels Accepted:  27000
# Generation Loop Itteration:  28000
# Labels Accepted:  28000
# Generation Loop Itteration:  29000
# Labels Accepted:  29000
# Generation Loop Itteration:  30000
# Labels Accepted:  30000
# Generation Loop Itteration:  31000
# Labels Accepted:  31000
# Generation Loop Itteration:  32000
# Labels Accepted:  32000
# Generation Loop Itteration:  33000
# Labels Accepted:  33000
# Generation Loop Itteration:  34000
# Labels Accepted:  34000
# Generation Loop Itteration:  35000
# Labels Accepted:  35000
# Generation Loop Itteration:  36000
# Labels Accepted:  36000
# Generation Loop Itteration:  37000
# Labels Accepted:  37000
# Generation Loop Itteration:  38000
# Labels Accepted:  38000
# Generation Loop Itteration:  39000
# Labels Accepted:  39000
# Generation Loop Itteration:  40000
# Labels Accepted:  40000
# Generation Loop Itteration:  41000
# Labels Accepted:  41000
# Generation Loop Itteration:  42000
# Labels Accepted:  42000
# Generation Loop Itteration:  43000
# Labels Accepted:  43000
# Generation Loop Itteration:  44000
# Labels Accepted:  44000
# Generation Loop Itteration:  45000
# Labels Accepted:  45000
# Generation Loop Itteration:  46000
# Labels Accepted:  46000
# Generation Loop Itteration:  47000
# Generation Loop Itteration:  48000
# Labels Accepted:  47000
# Generation Loop Itteration:  49000
# Labels Accepted:  48000
# Generation Loop Itteration:  50000
# Labels Accepted:  49000
# Generation Loop Itteration:  51000
# Labels Accepted:  50000
# Generation Loop Itteration:  52000
# Labels Accepted:  51000
# Generation Loop Itteration:  53000
# Labels Accepted:  52000
# Generation Loop Itteration:  54000
# Labels Accepted:  53000
# Generation Loop Itteration:  55000
# Labels Accepted:  54000
# Generation Loop Itteration:  56000
# Labels Accepted:  55000
# Generation Loop Itteration:  57000
# Labels Accepted:  56000
# Generation Loop Itteration:  58000
# Labels Accepted:  57000
# Generation Loop Itteration:  59000
# Labels Accepted:  58000
# Generation Loop Itteration:  60000
# Labels Accepted:  59000
# Generation Loop Itteration:  61000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  62000
# Labels Rejected by Uneven Label Distribution:  1000
# Labels Accepted:  61000
# Generation Loop Itteration:  63000
# Labels Accepted:  62000
# Generation Loop Itteration:  64000
# Labels Accepted:  63000
# Generation Loop Itteration:  65000
# Generation Loop Itteration:  66000
# Labels Accepted:  64000
# Generation Loop Itteration:  67000
# Labels Accepted:  65000
# Generation Loop Itteration:  68000
# Labels Accepted:  66000
# Generation Loop Itteration:  69000
# Labels Accepted:  67000
# Generation Loop Itteration:  70000
# Labels Accepted:  68000
# Generation Loop Itteration:  71000
# Labels Accepted:  69000
# Generation Loop Itteration:  72000
# Labels Accepted:  70000
# Generation Loop Itteration:  73000
# Labels Accepted:  71000
# Generation Loop Itteration:  74000
# Labels Rejected by Euclidian Distance:  1000
# Labels Accepted:  72000
# Generation Loop Itteration:  75000
# Labels Accepted:  73000
# Generation Loop Itteration:  76000
# Labels Accepted:  74000
# Generation Loop Itteration:  77000
# Labels Accepted:  75000
# Generation Loop Itteration:  78000
# Labels Accepted:  76000
# Generation Loop Itteration:  79000
# Labels Accepted:  77000
# Generation Loop Itteration:  80000
# Labels Accepted:  78000
# Generation Loop Itteration:  81000
# Labels Accepted:  79000
# Generation Loop Itteration:  82000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  83000
# Generation Loop Itteration:  84000
# Labels Accepted:  81000
# Generation Loop Itteration:  85000
# Labels Accepted:  82000
# Generation Loop Itteration:  86000
# Labels Accepted:  83000
# Generation Loop Itteration:  87000
# Labels Accepted:  84000
# Generation Loop Itteration:  88000
# Labels Accepted:  85000
# Generation Loop Itteration:  89000
# Labels Accepted:  86000
# Generation Loop Itteration:  90000
# Labels Accepted:  87000
# Generation Loop Itteration:  91000
# Labels Accepted:  88000
# Generation Loop Itteration:  92000
# Labels Accepted:  89000
# Generation Loop Itteration:  93000
# Labels Accepted:  90000
# Generation Loop Itteration:  94000
# Labels Accepted:  91000
# Generation Loop Itteration:  95000
# Labels Accepted:  92000
# Generation Loop Itteration:  96000
# Labels Accepted:  93000
# Generation Loop Itteration:  97000
# Labels Accepted:  94000
# Generation Loop Itteration:  98000
# Labels Accepted:  95000
# Generation Loop Itteration:  99000
# Labels Accepted:  96000
# Generation Loop Itteration:  100000
# Labels Accepted:  97000
# Generation Loop Itteration:  101000
# Labels Accepted:  98000
# Generation Loop Itteration:  102000
# Labels Accepted:  99000
# Generation Loop Itteration:  103000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:02:57.647399
# Generating dataset of class:  angle
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Rejected by Uneven Label Distribution:  1000
# Generation Loop Itteration:  3000
# Labels Accepted:  2000
# Generation Loop Itteration:  4000
# Labels Accepted:  3000
# Generation Loop Itteration:  5000
# Labels Accepted:  4000
# Generation Loop Itteration:  6000
# Labels Accepted:  5000
# Generation Loop Itteration:  7000
# Labels Accepted:  6000
# Generation Loop Itteration:  8000
# Labels Accepted:  7000
# Generation Loop Itteration:  9000
# Labels Accepted:  8000
# Generation Loop Itteration:  10000
# Labels Accepted:  9000
# Generation Loop Itteration:  11000
# Labels Accepted:  10000
# Generation Loop Itteration:  12000
# Labels Accepted:  11000
# Generation Loop Itteration:  13000
# Labels Accepted:  12000
# Generation Loop Itteration:  14000
# Labels Accepted:  13000
# Generation Loop Itteration:  15000
# Labels Accepted:  14000
# Generation Loop Itteration:  16000
# Labels Accepted:  15000
# Generation Loop Itteration:  17000
# Labels Accepted:  16000
# Generation Loop Itteration:  18000
# Labels Accepted:  17000
# Generation Loop Itteration:  19000
# Labels Accepted:  18000
# Generation Loop Itteration:  20000
# Labels Accepted:  19000
# Generation Loop Itteration:  21000
# Labels Accepted:  20000
# Generation Loop Itteration:  22000
# Labels Accepted:  21000
# Generation Loop Itteration:  23000
# Labels Accepted:  22000
# Generation Loop Itteration:  24000
# Labels Accepted:  23000
# Generation Loop Itteration:  25000
# Labels Accepted:  24000
# Generation Loop Itteration:  26000
# Labels Accepted:  25000
# Generation Loop Itteration:  27000
# Labels Accepted:  26000
# Generation Loop Itteration:  28000
# Labels Accepted:  27000
# Generation Loop Itteration:  29000
# Labels Accepted:  28000
# Generation Loop Itteration:  30000
# Labels Accepted:  29000
# Generation Loop Itteration:  31000
# Labels Accepted:  30000
# Generation Loop Itteration:  32000
# Labels Accepted:  31000
# Generation Loop Itteration:  33000
# Labels Accepted:  32000
# Generation Loop Itteration:  34000
# Labels Accepted:  33000
# Generation Loop Itteration:  35000
# Labels Accepted:  34000
# Generation Loop Itteration:  36000
# Labels Accepted:  35000
# Generation Loop Itteration:  37000
# Labels Accepted:  36000
# Generation Loop Itteration:  38000
# Labels Accepted:  37000
# Generation Loop Itteration:  39000
# Labels Accepted:  38000
# Generation Loop Itteration:  40000
# Labels Accepted:  39000
# Generation Loop Itteration:  41000
# Labels Accepted:  40000
# Generation Loop Itteration:  42000
# Labels Accepted:  41000
# Generation Loop Itteration:  43000
# Labels Accepted:  42000
# Generation Loop Itteration:  44000
# Labels Accepted:  43000
# Generation Loop Itteration:  45000
# Labels Accepted:  44000
# Generation Loop Itteration:  46000
# Labels Accepted:  45000
# Generation Loop Itteration:  47000
# Labels Accepted:  46000
# Generation Loop Itteration:  48000
# Labels Accepted:  47000
# Generation Loop Itteration:  49000
# Labels Accepted:  48000
# Generation Loop Itteration:  50000
# Labels Accepted:  49000
# Generation Loop Itteration:  51000
# Labels Accepted:  50000
# Generation Loop Itteration:  52000
# Labels Accepted:  51000
# Generation Loop Itteration:  53000
# Labels Accepted:  52000
# Generation Loop Itteration:  54000
# Labels Accepted:  53000
# Generation Loop Itteration:  55000
# Labels Accepted:  54000
# Generation Loop Itteration:  56000
# Labels Accepted:  55000
# Generation Loop Itteration:  57000
# Labels Accepted:  56000
# Generation Loop Itteration:  58000
# Labels Accepted:  57000
# Generation Loop Itteration:  59000
# Labels Accepted:  58000
# Generation Loop Itteration:  60000
# Labels Accepted:  59000
# Generation Loop Itteration:  61000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  62000
# Generation Loop Itteration:  63000
# Labels Accepted:  61000
# Labels Rejected by Uneven Label Distribution:  2000
# Generation Loop Itteration:  64000
# Labels Accepted:  62000
# Generation Loop Itteration:  65000
# Labels Accepted:  63000
# Generation Loop Itteration:  66000
# Labels Accepted:  64000
# Generation Loop Itteration:  67000
# Labels Accepted:  65000
# Generation Loop Itteration:  68000
# Labels Accepted:  66000
# Generation Loop Itteration:  69000
# Labels Accepted:  67000
# Generation Loop Itteration:  70000
# Labels Accepted:  68000
# Generation Loop Itteration:  71000
# Labels Accepted:  69000
# Generation Loop Itteration:  72000
# Labels Accepted:  70000
# Generation Loop Itteration:  73000
# Generation Loop Itteration:  74000
# Labels Accepted:  71000
# Generation Loop Itteration:  75000
# Labels Accepted:  72000
# Generation Loop Itteration:  76000
# Labels Accepted:  73000
# Generation Loop Itteration:  77000
# Labels Accepted:  74000
# Generation Loop Itteration:  78000
# Labels Accepted:  75000
# Generation Loop Itteration:  79000
# Labels Accepted:  76000
# Generation Loop Itteration:  80000
# Labels Accepted:  77000
# Generation Loop Itteration:  81000
# Labels Accepted:  78000
# Generation Loop Itteration:  82000
# Labels Accepted:  79000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  83000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  84000
# Labels Rejected by Uneven Label Distribution:  3000
# Generation Loop Itteration:  85000
# Labels Accepted:  81000
# Generation Loop Itteration:  86000
# Labels Accepted:  82000
# Generation Loop Itteration:  87000
# Labels Accepted:  83000
# Generation Loop Itteration:  88000
# Labels Accepted:  84000
# Generation Loop Itteration:  89000
# Labels Accepted:  85000
# Generation Loop Itteration:  90000
# Labels Accepted:  86000
# Generation Loop Itteration:  91000
# Labels Accepted:  87000
# Generation Loop Itteration:  92000
# Labels Accepted:  88000
# Generation Loop Itteration:  93000
# Labels Accepted:  89000
# Generation Loop Itteration:  94000
# Generation Loop Itteration:  95000
# Labels Accepted:  90000
# Generation Loop Itteration:  96000
# Labels Accepted:  91000
# Generation Loop Itteration:  97000
# Labels Accepted:  92000
# Generation Loop Itteration:  98000
# Labels Accepted:  93000
# Generation Loop Itteration:  99000
# Labels Accepted:  94000
# Generation Loop Itteration:  100000
# Labels Accepted:  95000
# Generation Loop Itteration:  101000
# Labels Accepted:  96000
# Generation Loop Itteration:  102000
# Labels Accepted:  97000
# Generation Loop Itteration:  103000
# Labels Accepted:  98000
# Generation Loop Itteration:  104000
# Labels Accepted:  99000
# Generation Loop Itteration:  105000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:04:41.767285
# Generating dataset of class:  length
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Accepted:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  6000
# Generation Loop Itteration:  7000
# Labels Accepted:  7000
# Generation Loop Itteration:  8000
# Labels Accepted:  8000
# Generation Loop Itteration:  9000
# Labels Accepted:  9000
# Generation Loop Itteration:  10000
# Labels Accepted:  10000
# Generation Loop Itteration:  11000
# Labels Accepted:  11000
# Generation Loop Itteration:  12000
# Labels Accepted:  12000
# Generation Loop Itteration:  13000
# Labels Accepted:  13000
# Generation Loop Itteration:  14000
# Labels Accepted:  14000
# Generation Loop Itteration:  15000
# Labels Accepted:  15000
# Generation Loop Itteration:  16000
# Labels Accepted:  16000
# Generation Loop Itteration:  17000
# Labels Accepted:  17000
# Generation Loop Itteration:  18000
# Labels Accepted:  18000
# Generation Loop Itteration:  19000
# Labels Accepted:  19000
# Generation Loop Itteration:  20000
# Labels Accepted:  20000
# Generation Loop Itteration:  21000
# Labels Accepted:  21000
# Generation Loop Itteration:  22000
# Labels Accepted:  22000
# Generation Loop Itteration:  23000
# Labels Accepted:  23000
# Generation Loop Itteration:  24000
# Labels Accepted:  24000
# Generation Loop Itteration:  25000
# Labels Accepted:  25000
# Generation Loop Itteration:  26000
# Labels Accepted:  26000
# Generation Loop Itteration:  27000
# Labels Accepted:  27000
# Generation Loop Itteration:  28000
# Labels Accepted:  28000
# Generation Loop Itteration:  29000
# Labels Accepted:  29000
# Generation Loop Itteration:  30000
# Labels Accepted:  30000
# Generation Loop Itteration:  31000
# Labels Accepted:  31000
# Generation Loop Itteration:  32000
# Labels Accepted:  32000
# Generation Loop Itteration:  33000
# Labels Accepted:  33000
# Generation Loop Itteration:  34000
# Generation Loop Itteration:  35000
# Labels Accepted:  34000
# Generation Loop Itteration:  36000
# Labels Accepted:  35000
# Generation Loop Itteration:  37000
# Labels Accepted:  36000
# Generation Loop Itteration:  38000
# Labels Accepted:  37000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  39000
# Labels Accepted:  38000
# Generation Loop Itteration:  40000
# Labels Accepted:  39000
# Generation Loop Itteration:  41000
# Labels Accepted:  40000
# Generation Loop Itteration:  42000
# Labels Accepted:  41000
# Generation Loop Itteration:  43000
# Labels Accepted:  42000
# Generation Loop Itteration:  44000
# Labels Accepted:  43000
# Generation Loop Itteration:  45000
# Labels Accepted:  44000
# Generation Loop Itteration:  46000
# Labels Accepted:  45000
# Generation Loop Itteration:  47000
# Labels Accepted:  46000
# Generation Loop Itteration:  48000
# Labels Accepted:  47000
# Generation Loop Itteration:  49000
# Labels Accepted:  48000
# Generation Loop Itteration:  50000
# Labels Accepted:  49000
# Generation Loop Itteration:  51000
# Generation Loop Itteration:  52000
# Labels Accepted:  50000
# Generation Loop Itteration:  53000
# Labels Accepted:  51000
# Generation Loop Itteration:  54000
# Labels Rejected by Euclidian Distance:  2000
# Labels Accepted:  52000
# Generation Loop Itteration:  55000
# Labels Accepted:  53000
# Generation Loop Itteration:  56000
# Labels Accepted:  54000
# Generation Loop Itteration:  57000
# Labels Accepted:  55000
# Generation Loop Itteration:  58000
# Labels Accepted:  56000
# Generation Loop Itteration:  59000
# Labels Accepted:  57000
# Generation Loop Itteration:  60000
# Labels Accepted:  58000
# Generation Loop Itteration:  61000
# Labels Accepted:  59000
# Generation Loop Itteration:  62000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  63000
# Generation Loop Itteration:  64000
# Labels Accepted:  61000
# Generation Loop Itteration:  65000
# Labels Accepted:  62000
# Generation Loop Itteration:  66000
# Labels Accepted:  63000
# Labels Rejected by Euclidian Distance:  3000
# Generation Loop Itteration:  67000
# Labels Accepted:  64000
# Generation Loop Itteration:  68000
# Labels Accepted:  65000
# Generation Loop Itteration:  69000
# Labels Accepted:  66000
# Generation Loop Itteration:  70000
# Labels Accepted:  67000
# Generation Loop Itteration:  71000
# Labels Accepted:  68000
# Generation Loop Itteration:  72000
# Generation Loop Itteration:  73000
# Labels Accepted:  69000
# Generation Loop Itteration:  74000
# Labels Accepted:  70000
# Generation Loop Itteration:  75000
# Labels Accepted:  71000
# Generation Loop Itteration:  76000
# Labels Accepted:  72000
# Generation Loop Itteration:  77000
# Labels Rejected by Euclidian Distance:  4000
# Labels Accepted:  73000
# Generation Loop Itteration:  78000
# Labels Accepted:  74000
# Generation Loop Itteration:  79000
# Labels Accepted:  75000
# Generation Loop Itteration:  80000
# Labels Accepted:  76000
# Generation Loop Itteration:  81000
# Labels Accepted:  77000
# Generation Loop Itteration:  82000
# Generation Loop Itteration:  83000
# Labels Accepted:  78000
# Generation Loop Itteration:  84000
# Labels Accepted:  79000
# Generation Loop Itteration:  85000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  86000
# Labels Rejected by Euclidian Distance:  5000
# Labels Accepted:  81000
# Generation Loop Itteration:  87000
# Labels Accepted:  82000
# Generation Loop Itteration:  88000
# Labels Accepted:  83000
# Generation Loop Itteration:  89000
# Generation Loop Itteration:  90000
# Labels Accepted:  84000
# Generation Loop Itteration:  91000
# Labels Accepted:  85000
# Generation Loop Itteration:  92000
# Labels Accepted:  86000
# Generation Loop Itteration:  93000
# Labels Accepted:  87000
# Generation Loop Itteration:  94000
# Labels Accepted:  88000
# Generation Loop Itteration:  95000
# Labels Rejected by Euclidian Distance:  6000
# Labels Accepted:  89000
# Generation Loop Itteration:  96000
# Labels Accepted:  90000
# Generation Loop Itteration:  97000
# Generation Loop Itteration:  98000
# Labels Accepted:  91000
# Generation Loop Itteration:  99000
# Labels Accepted:  92000
# Generation Loop Itteration:  100000
# Labels Accepted:  93000
# Generation Loop Itteration:  101000
# Labels Accepted:  94000
# Generation Loop Itteration:  102000
# Labels Rejected by Euclidian Distance:  7000
# Labels Accepted:  95000
# Generation Loop Itteration:  103000
# Labels Accepted:  96000
# Generation Loop Itteration:  104000
# Labels Accepted:  97000
# Generation Loop Itteration:  105000
# Generation Loop Itteration:  106000
# Labels Accepted:  98000
# Generation Loop Itteration:  107000
# Labels Accepted:  99000
# Generation Loop Itteration:  108000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:01:50.964198
# Generating dataset of class:  direction
# Generation Loop Itteration:  1000
# Labels Rejected by Uneven Label Distribution:  1000
# Generation Loop Itteration:  2000
# Labels Rejected by Uneven Label Distribution:  2000
# Generation Loop Itteration:  3000
# Labels Rejected by Uneven Label Distribution:  3000
# Generation Loop Itteration:  4000
# Labels Rejected by Uneven Label Distribution:  4000
# Generation Loop Itteration:  5000
# Labels Rejected by Uneven Label Distribution:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  1000
# Generation Loop Itteration:  7000
# Labels Rejected by Uneven Label Distribution:  6000
# Generation Loop Itteration:  8000
# Labels Accepted:  2000
# Generation Loop Itteration:  9000
# Labels Rejected by Uneven Label Distribution:  7000
# Generation Loop Itteration:  10000
# Labels Accepted:  3000
# Generation Loop Itteration:  11000
# Labels Accepted:  4000
# Generation Loop Itteration:  12000
# Labels Accepted:  5000
# Generation Loop Itteration:  13000
# Labels Accepted:  6000
# Generation Loop Itteration:  14000
# Labels Accepted:  7000
# Generation Loop Itteration:  15000
# Labels Rejected by Uneven Label Distribution:  8000
# Generation Loop Itteration:  16000
# Labels Accepted:  8000
# Generation Loop Itteration:  17000
# Labels Accepted:  9000
# Generation Loop Itteration:  18000
# Labels Accepted:  10000
# Generation Loop Itteration:  19000
# Labels Accepted:  11000
# Generation Loop Itteration:  20000
# Labels Accepted:  12000
# Generation Loop Itteration:  21000
# Labels Accepted:  13000
# Generation Loop Itteration:  22000
# Labels Accepted:  14000
# Generation Loop Itteration:  23000
# Labels Accepted:  15000
# Generation Loop Itteration:  24000
# Labels Accepted:  16000
# Generation Loop Itteration:  25000
# Labels Accepted:  17000
# Generation Loop Itteration:  26000
# Labels Accepted:  18000
# Generation Loop Itteration:  27000
# Labels Accepted:  19000
# Generation Loop Itteration:  28000
# Labels Accepted:  20000
# Generation Loop Itteration:  29000
# Labels Accepted:  21000
# Generation Loop Itteration:  30000
# Labels Accepted:  22000
# Generation Loop Itteration:  31000
# Labels Accepted:  23000
# Generation Loop Itteration:  32000
# Labels Accepted:  24000
# Generation Loop Itteration:  33000
# Labels Accepted:  25000
# Generation Loop Itteration:  34000
# Labels Accepted:  26000
# Generation Loop Itteration:  35000
# Labels Accepted:  27000
# Generation Loop Itteration:  36000
# Labels Accepted:  28000
# Generation Loop Itteration:  37000
# Labels Accepted:  29000
# Generation Loop Itteration:  38000
# Labels Accepted:  30000
# Generation Loop Itteration:  39000
# Labels Accepted:  31000
# Generation Loop Itteration:  40000
# Labels Accepted:  32000
# Generation Loop Itteration:  41000
# Labels Accepted:  33000
# Generation Loop Itteration:  42000
# Labels Accepted:  34000
# Generation Loop Itteration:  43000
# Labels Accepted:  35000
# Generation Loop Itteration:  44000
# Labels Accepted:  36000
# Generation Loop Itteration:  45000
# Labels Accepted:  37000
# Generation Loop Itteration:  46000
# Labels Accepted:  38000
# Generation Loop Itteration:  47000
# Labels Accepted:  39000
# Generation Loop Itteration:  48000
# Labels Accepted:  40000
# Generation Loop Itteration:  49000
# Labels Accepted:  41000
# Generation Loop Itteration:  50000
# Labels Accepted:  42000
# Generation Loop Itteration:  51000
# Labels Accepted:  43000
# Generation Loop Itteration:  52000
# Labels Accepted:  44000
# Generation Loop Itteration:  53000
# Labels Accepted:  45000
# Generation Loop Itteration:  54000
# Labels Accepted:  46000
# Generation Loop Itteration:  55000
# Labels Accepted:  47000
# Generation Loop Itteration:  56000
# Labels Accepted:  48000
# Generation Loop Itteration:  57000
# Labels Accepted:  49000
# Generation Loop Itteration:  58000
# Labels Accepted:  50000
# Generation Loop Itteration:  59000
# Labels Accepted:  51000
# Generation Loop Itteration:  60000
# Labels Accepted:  52000
# Generation Loop Itteration:  61000
# Labels Accepted:  53000
# Generation Loop Itteration:  62000
# Labels Accepted:  54000
# Generation Loop Itteration:  63000
# Labels Accepted:  55000
# Generation Loop Itteration:  64000
# Labels Accepted:  56000
# Generation Loop Itteration:  65000
# Labels Accepted:  57000
# Generation Loop Itteration:  66000
# Labels Accepted:  58000
# Generation Loop Itteration:  67000
# Labels Accepted:  59000
# Generation Loop Itteration:  68000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  69000
# Labels Rejected by Uneven Label Distribution:  9000
# Generation Loop Itteration:  70000
# Labels Rejected by Uneven Label Distribution:  10000
# Generation Loop Itteration:  71000
# Labels Rejected by Uneven Label Distribution:  11000
# Generation Loop Itteration:  72000
# Labels Rejected by Uneven Label Distribution:  12000
# Generation Loop Itteration:  73000
# Labels Rejected by Uneven Label Distribution:  13000
# Generation Loop Itteration:  74000
# Labels Accepted:  61000
# Generation Loop Itteration:  75000
# Labels Rejected by Uneven Label Distribution:  14000
# Generation Loop Itteration:  76000
# Labels Accepted:  62000
# Generation Loop Itteration:  77000
# Labels Accepted:  63000
# Generation Loop Itteration:  78000
# Labels Rejected by Uneven Label Distribution:  15000
# Generation Loop Itteration:  79000
# Labels Accepted:  64000
# Generation Loop Itteration:  80000
# Labels Accepted:  65000
# Generation Loop Itteration:  81000
# Labels Accepted:  66000
# Generation Loop Itteration:  82000
# Labels Accepted:  67000
# Generation Loop Itteration:  83000
# Labels Accepted:  68000
# Generation Loop Itteration:  84000
# Labels Accepted:  69000
# Generation Loop Itteration:  85000
# Labels Accepted:  70000
# Generation Loop Itteration:  86000
# Labels Rejected by Uneven Label Distribution:  16000
# Generation Loop Itteration:  87000
# Labels Accepted:  71000
# Generation Loop Itteration:  88000
# Labels Accepted:  72000
# Generation Loop Itteration:  89000
# Labels Accepted:  73000
# Generation Loop Itteration:  90000
# Labels Accepted:  74000
# Generation Loop Itteration:  91000
# Labels Accepted:  75000
# Generation Loop Itteration:  92000
# Labels Accepted:  76000
# Generation Loop Itteration:  93000
# Labels Accepted:  77000
# Generation Loop Itteration:  94000
# Labels Accepted:  78000
# Generation Loop Itteration:  95000
# Labels Accepted:  79000
# Generation Loop Itteration:  96000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  97000
# Labels Rejected by Uneven Label Distribution:  17000
# Generation Loop Itteration:  98000
# Labels Rejected by Uneven Label Distribution:  18000
# Generation Loop Itteration:  99000
# Labels Rejected by Uneven Label Distribution:  19000
# Generation Loop Itteration:  100000
# Labels Rejected by Uneven Label Distribution:  20000
# Generation Loop Itteration:  101000
# Labels Accepted:  81000
# Generation Loop Itteration:  102000
# Labels Rejected by Uneven Label Distribution:  21000
# Generation Loop Itteration:  103000
# Labels Rejected by Uneven Label Distribution:  22000
# Generation Loop Itteration:  104000
# Labels Accepted:  82000
# Generation Loop Itteration:  105000
# Labels Accepted:  83000
# Generation Loop Itteration:  106000
# Labels Rejected by Uneven Label Distribution:  23000
# Generation Loop Itteration:  107000
# Labels Accepted:  84000
# Generation Loop Itteration:  108000
# Labels Accepted:  85000
# Generation Loop Itteration:  109000
# Labels Accepted:  86000
# Generation Loop Itteration:  110000
# Labels Accepted:  87000
# Generation Loop Itteration:  111000
# Labels Accepted:  88000
# Generation Loop Itteration:  112000
# Labels Accepted:  89000
# Generation Loop Itteration:  113000
# Labels Accepted:  90000
# Generation Loop Itteration:  114000
# Labels Accepted:  91000
# Generation Loop Itteration:  115000
# Labels Accepted:  92000
# Generation Loop Itteration:  116000
# Labels Accepted:  93000
# Generation Loop Itteration:  117000
# Labels Accepted:  94000
# Generation Loop Itteration:  118000
# Labels Accepted:  95000
# Generation Loop Itteration:  119000
# Labels Accepted:  96000
# Generation Loop Itteration:  120000
# Labels Accepted:  97000
# Generation Loop Itteration:  121000
# Labels Accepted:  98000
# Generation Loop Itteration:  122000
# Labels Rejected by Uneven Label Distribution:  24000
# Generation Loop Itteration:  123000
# Labels Accepted:  99000
# Generation Loop Itteration:  124000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:04:50.487284
# Generating dataset of class:  curvature
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Accepted:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  6000
# Generation Loop Itteration:  7000
# Labels Accepted:  7000
# Generation Loop Itteration:  8000
# Labels Accepted:  8000
# Generation Loop Itteration:  9000
# Labels Accepted:  9000
# Generation Loop Itteration:  10000
# Labels Accepted:  10000
# Generation Loop Itteration:  11000
# Labels Accepted:  11000
# Generation Loop Itteration:  12000
# Labels Accepted:  12000
# Generation Loop Itteration:  13000
# Labels Accepted:  13000
# Generation Loop Itteration:  14000
# Labels Accepted:  14000
# Generation Loop Itteration:  15000
# Labels Accepted:  15000
# Generation Loop Itteration:  16000
# Labels Accepted:  16000
# Generation Loop Itteration:  17000
# Labels Accepted:  17000
# Generation Loop Itteration:  18000
# Labels Accepted:  18000
# Generation Loop Itteration:  19000
# Labels Accepted:  19000
# Generation Loop Itteration:  20000
# Labels Accepted:  20000
# Generation Loop Itteration:  21000
# Labels Accepted:  21000
# Generation Loop Itteration:  22000
# Labels Accepted:  22000
# Generation Loop Itteration:  23000
# Labels Accepted:  23000
# Generation Loop Itteration:  24000
# Labels Accepted:  24000
# Generation Loop Itteration:  25000
# Labels Accepted:  25000
# Generation Loop Itteration:  26000
# Labels Accepted:  26000
# Generation Loop Itteration:  27000
# Labels Accepted:  27000
# Generation Loop Itteration:  28000
# Labels Accepted:  28000
# Generation Loop Itteration:  29000
# Labels Accepted:  29000
# Generation Loop Itteration:  30000
# Labels Accepted:  30000
# Generation Loop Itteration:  31000
# Labels Accepted:  31000
# Generation Loop Itteration:  32000
# Labels Accepted:  32000
# Generation Loop Itteration:  33000
# Labels Accepted:  33000
# Generation Loop Itteration:  34000
# Labels Accepted:  34000
# Generation Loop Itteration:  35000
# Labels Accepted:  35000
# Generation Loop Itteration:  36000
# Labels Accepted:  36000
# Generation Loop Itteration:  37000
# Labels Accepted:  37000
# Generation Loop Itteration:  38000
# Labels Accepted:  38000
# Generation Loop Itteration:  39000
# Labels Accepted:  39000
# Generation Loop Itteration:  40000
# Labels Accepted:  40000
# Generation Loop Itteration:  41000
# Labels Accepted:  41000
# Generation Loop Itteration:  42000
# Labels Accepted:  42000
# Generation Loop Itteration:  43000
# Generation Loop Itteration:  44000
# Labels Accepted:  43000
# Generation Loop Itteration:  45000
# Labels Accepted:  44000
# Generation Loop Itteration:  46000
# Labels Accepted:  45000
# Generation Loop Itteration:  47000
# Labels Accepted:  46000
# Generation Loop Itteration:  48000
# Labels Accepted:  47000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  49000
# Labels Accepted:  48000
# Generation Loop Itteration:  50000
# Labels Accepted:  49000
# Generation Loop Itteration:  51000
# Labels Accepted:  50000
# Generation Loop Itteration:  52000
# Labels Accepted:  51000
# Generation Loop Itteration:  53000
# Labels Accepted:  52000
# Generation Loop Itteration:  54000
# Labels Accepted:  53000
# Generation Loop Itteration:  55000
# Labels Accepted:  54000
# Generation Loop Itteration:  56000
# Labels Accepted:  55000
# Generation Loop Itteration:  57000
# Labels Accepted:  56000
# Generation Loop Itteration:  58000
# Labels Accepted:  57000
# Generation Loop Itteration:  59000
# Labels Accepted:  58000
# Generation Loop Itteration:  60000
# Labels Accepted:  59000
# Generation Loop Itteration:  61000
# Labels Accepted:  60000
# Finished Generating:  train
# Generation Loop Itteration:  62000
# Generation Loop Itteration:  63000
# Labels Accepted:  61000
# Generation Loop Itteration:  64000
# Labels Accepted:  62000
# Generation Loop Itteration:  65000
# Labels Accepted:  63000
# Generation Loop Itteration:  66000
# Labels Accepted:  64000
# Generation Loop Itteration:  67000
# Labels Accepted:  65000
# Generation Loop Itteration:  68000
# Labels Accepted:  66000
# Labels Rejected by Euclidian Distance:  2000
# Generation Loop Itteration:  69000
# Labels Accepted:  67000
# Generation Loop Itteration:  70000
# Labels Accepted:  68000
# Generation Loop Itteration:  71000
# Labels Accepted:  69000
# Generation Loop Itteration:  72000
# Labels Accepted:  70000
# Generation Loop Itteration:  73000
# Labels Accepted:  71000
# Generation Loop Itteration:  74000
# Labels Accepted:  72000
# Generation Loop Itteration:  75000
# Labels Accepted:  73000
# Generation Loop Itteration:  76000
# Labels Accepted:  74000
# Generation Loop Itteration:  77000
# Generation Loop Itteration:  78000
# Labels Accepted:  75000
# Generation Loop Itteration:  79000
# Labels Accepted:  76000
# Generation Loop Itteration:  80000
# Labels Accepted:  77000
# Generation Loop Itteration:  81000
# Labels Accepted:  78000
# Generation Loop Itteration:  82000
# Labels Accepted:  79000
# Generation Loop Itteration:  83000
# Labels Accepted:  80000
# Finished Generating:  val
# Generation Loop Itteration:  84000
# Labels Accepted:  81000
# Generation Loop Itteration:  85000
# Labels Rejected by Euclidian Distance:  3000
# Labels Accepted:  82000
# Generation Loop Itteration:  86000
# Labels Accepted:  83000
# Generation Loop Itteration:  87000
# Labels Accepted:  84000
# Generation Loop Itteration:  88000
# Labels Accepted:  85000
# Generation Loop Itteration:  89000
# Generation Loop Itteration:  90000
# Labels Accepted:  86000
# Generation Loop Itteration:  91000
# Labels Accepted:  87000
# Generation Loop Itteration:  92000
# Labels Accepted:  88000
# Generation Loop Itteration:  93000
# Labels Accepted:  89000
# Generation Loop Itteration:  94000
# Labels Accepted:  90000
# Generation Loop Itteration:  95000
# Labels Accepted:  91000
# Generation Loop Itteration:  96000
# Labels Accepted:  92000
# Generation Loop Itteration:  97000
# Labels Accepted:  93000
# Generation Loop Itteration:  98000
# Labels Accepted:  94000
# Labels Rejected by Euclidian Distance:  4000
# Generation Loop Itteration:  99000
# Labels Accepted:  95000
# Generation Loop Itteration:  100000
# Labels Accepted:  96000
# Generation Loop Itteration:  101000
# Labels Accepted:  97000
# Generation Loop Itteration:  102000
# Generation Loop Itteration:  103000
# Labels Accepted:  98000
# Generation Loop Itteration:  104000
# Labels Accepted:  99000
# Generation Loop Itteration:  105000
# Labels Accepted:  100000
# Finished Generating:  test
# Evaluation time  0:02:09.481223
# Generating dataset of class:  area
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  6000
# Labels Accepted:  5000
# Generation Loop Itteration:  7000
# Labels Accepted:  6000
# Finished Generating:  train
# Generation Loop Itteration:  8000
# Labels Rejected by Euclidian Distance:  2000
# Generation Loop Itteration:  9000
# Labels Accepted:  7000
# Generation Loop Itteration:  10000
# Labels Rejected by Euclidian Distance:  3000
# Generation Loop Itteration:  11000
# Labels Accepted:  8000
# Finished Generating:  val
# Generation Loop Itteration:  12000
# Labels Rejected by Euclidian Distance:  4000
# Generation Loop Itteration:  13000
# Labels Rejected by Euclidian Distance:  5000
# Generation Loop Itteration:  14000
# Labels Accepted:  9000
# Generation Loop Itteration:  15000
# Labels Rejected by Euclidian Distance:  6000
# Generation Loop Itteration:  16000
# Generation Loop Itteration:  17000
# Labels Accepted:  10000
# Finished Generating:  test
# Evaluation time  0:00:11.025213
# Generating dataset of class:  volume
# Generation Loop Itteration:  1000
# Labels Accepted:  1000
# Generation Loop Itteration:  2000
# Labels Accepted:  2000
# Generation Loop Itteration:  3000
# Labels Accepted:  3000
# Generation Loop Itteration:  4000
# Labels Accepted:  4000
# Generation Loop Itteration:  5000
# Labels Accepted:  5000
# Generation Loop Itteration:  6000
# Labels Accepted:  6000
# Finished Generating:  train
# Generation Loop Itteration:  7000
# Labels Rejected by Euclidian Distance:  1000
# Generation Loop Itteration:  8000
# Labels Accepted:  7000
# Generation Loop Itteration:  9000
# Labels Accepted:  8000
# Finished Generating:  val
# Generation Loop Itteration:  10000
# Labels Accepted:  9000
# Generation Loop Itteration:  11000
# Labels Rejected by Euclidian Distance:  2000
# Generation Loop Itteration:  12000
# Labels Accepted:  10000
# Finished Generating:  test
# Evaluation time  0:00:14.678205

# %%
import pickle
with open("output/" + "area" + "/distributions_label_distribution_0.p", "rb") as file:
        data = pickle.load(file)
        pyplot.figure()
        x = sorted(list(map(int, data["area"].keys())))
        print(len(x))
        y = [data["area"][str(key)] for key in x]
        pyplot.bar(x=x,height=y)
        pyplot.xlabel("area")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-bbcfd98c10e5> in <module>
#       1 import pickle
# ----> 2 with open("output/" + "area" + "/distributions_label_distribution_0.p", "rb") as file:
#       3         data = pickle.load(file)
#       4         pyplot.figure()
#       5         x = sorted(list(map(int, data["area"].keys())))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output/area/distributions_label_distribution_0.p'

# %%
import pickle
with open("output/" + "volume" + "/distributions_label_distribution_0.p", "rb") as file:
        data = pickle.load(file)
        pyplot.figure()
        x = sorted(list(map(int, data["volume"].keys())))
        print(len(x))
        y = [data["volume"][str(key)] for key in x]
        pyplot.bar(x=x,height=y)
        pyplot.xlabel("volume")

# %%
import pickle
with open("output/" + "curvature" + "/distributions_label_distribution_0.p", "rb") as file:
        data = pickle.load(file)
        pyplot.figure()
        x = sorted(list(map(int, data["curvature"].keys())))
        print(len(x))
        y = [data["curvature"][str(key)] for key in x]
        pyplot.bar(x=x,height=y)
        pyplot.xlabel("curvature")

# %%
import pickle
with open("output/" + "position_common_scale" + "/distributions_label_distribution_0.p", "rb") as file:
        data = pickle.load(file)
        pyplot.figure()
        x = sorted(list(map(int, data["position_common_scale"].keys())))
        print(len(x))
        y = [data["position_common_scale"][str(key)] for key in x]
        pyplot.bar(x=x,height=y)
        pyplot.xlabel("position_common_scale")
