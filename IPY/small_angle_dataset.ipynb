# %%
# %pylab inline
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
DATAFOLDER = '/home/d/Dropbox/PROJECTS/LE-V-EL/'

# %%
a = np.load(os.path.join(DATAFOLDER, 'train_0.npz'))

# %%
list(a.keys())
# Out:
# ['label', 'image', 'mask', 'bbox', 'sparse', 'parameters']

# %%
images = a['image']
masks = a['mask']
labels = a['label']
bbox = a['bbox']
sparse = a['sparse']
params = a['parameters']

# %%
labels[0]
# Out:
# array([37, 53, 57, 21], dtype=uint8)

# %%
image.shape
# Out:
# (600, 100, 150)

# %%
imshow(image[0])

# %%
image.dtype
# Out:
# dtype('float64')

# %%
masks.shape
# Out:
# (600, 100, 150, 4)

# %%
masks.dtype
# Out:
# dtype('uint8')

# %%
imshow(masks[0,:,:,0])

# %%
imshow(masks[0,:,:,1])

# %%
imshow(masks[0,:,:,2])

# %%
imshow(masks[0,:,:,3])

# %%
masks.min(), masks.max()
# Out:
# (0, 1)

# %%
bbox[0]
# Out:
# array([[  9,   9,  21,  19],
#        [ 40,  56,  50,  69],
#        [ 49,  94,  61, 104],
#        [ 76, 132,  81, 144]], dtype=int32)

# %%
plt.figure(figsize=(10,10))
imshow(masks[0,:,:,0])

# %%
m = masks[0,:,:,0]

# %%
cropped0 = m[bbox[0][0][0]:bbox[0][0][2], bbox[0][0][1]:bbox[0][0][3]]

# %%
padded0 = np.pad(cropped0, pad_width=int((100-cropped0.shape[0])/2), mode='constant')

# %%
padded0.shape
# Out:
# (100, 98)

# %%
imshow(padded0)

# %%
sparse[0]
# Out:
# array([[ 20,  18,  37, 218],
#        [ 40,  56,  53,   0],
#        [ 60,  94,  57, 269],
#        [ 80, 132,  21, 336]])

# %%
params[3]
# Out:
# 1101996057600000000

# %%
with open(os.path.join(DATAFOLDER, 'train_0.npz'), "rb") as file:
    data = pickle.load(file)

# %%
plt.bar(range(len(data.label_distribution)),data.label_distribution)
