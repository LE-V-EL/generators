# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from datasets import PartitionedDataset
# Out:
# /home/jwfree/anaconda3/envs/generators/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jwfree/anaconda3/envs/generators/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jwfree/anaconda3/envs/generators/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
part = PartitionedDataset()

# %%
part.generate()
# Out:
# itteration:  1000
# Finished Generating:  train
# Finished Generating:  val
# Finished Generating:  test
# Evaluation time  0:00:09.008288

# %%
part.validate_labels()
# Out:
# validating:  0
# True

# %%
big = PartitionedDataset({'b_train': 6000, "b_val": 2000, "b_test": 2000})
big.generate()
big.validate_labels()
# Out:
# itteration:  1000
# labels:  1000
# itteration:  2000
# labels:  2000
# itteration:  3000
# itteration:  4000
# labels:  3000
# itteration:  5000
# labels:  4000
# itteration:  6000
# labels:  5000
# itteration:  7000
# labels:  6000
# Finished Generating:  b_train
# itteration:  8000
# itteration:  9000
# itteration:  10000
# labels:  7000
# itteration:  11000
# labels:  8000
# Finished Generating:  b_val
# itteration:  12000
# itteration:  13000
# itteration:  14000
# labels:  9000
# itteration:  15000
# itteration:  16000
# labels:  10000
# Finished Generating:  b_test
# Evaluation time  0:12:34.424968
# validating:  0
# validating:  1000
# validating:  2000
# validating:  3000
# validating:  4000
# validating:  5000
# validating:  6000
# validating:  7000
# validating:  8000
# validating:  9000
# True

# %%
big_naive = PartitionedDataset({'train': 6000, "val": 2000, "test": 2000}, naive=True)
big_naive.generate()
big_naive.validate_labels()
# Out:
# itteration:  1000
# itteration:  2000
# labels:  1000
# itteration:  3000
# labels:  2000
# itteration:  4000
# labels:  3000
# itteration:  5000
# labels:  4000
# itteration:  6000
# labels:  5000
# itteration:  7000
# itteration:  8000
# labels:  6000
# Finished Generating:  train
# itteration:  9000
# itteration:  10000
# labels:  7000
# itteration:  11000
# itteration:  12000
# labels:  8000
# Finished Generating:  val
# itteration:  13000
# itteration:  14000
# itteration:  15000
# labels:  9000
# itteration:  16000
# labels:  10000
# Finished Generating:  test
# Evaluation time  0:06:40.339572

# %%
bigger = PartitionedDataset({"train": 60000, "val": 20000, "test": 20000})
bigger.generate()
bigger.validate_labels()
# Out:
# itteration:  1000
# labels:  1000
# itteration:  2000
# labels:  2000
# itteration:  3000
# itteration:  4000
# labels:  3000
# itteration:  5000
# labels:  4000
# itteration:  6000
# labels:  5000
# itteration:  7000
# labels:  6000
# itteration:  8000
# labels:  7000
# itteration:  9000
# labels:  8000
# itteration:  10000
# labels:  9000
# itteration:  11000
# labels:  10000
# itteration:  12000
# itteration:  13000
# labels:  11000
# itteration:  14000
# labels:  12000
# itteration:  15000
# labels:  13000
# itteration:  16000
# labels:  14000
# itteration:  17000
# itteration:  18000
# labels:  15000
# itteration:  19000
# labels:  16000
# itteration:  20000
# labels:  17000
# itteration:  21000
# labels:  18000
# itteration:  22000
# labels:  19000
# itteration:  23000
# labels:  20000
# itteration:  24000
# itteration:  25000
# labels:  21000
# itteration:  26000
# labels:  22000
# itteration:  27000
# itteration:  28000
# labels:  23000
# itteration:  29000
# labels:  24000
# ...

# %%
import pickle
with open("output/bigger.p", "wb") as file:
    pickle.dump(bigger, file)
