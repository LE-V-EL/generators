# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datasets import PartitionedDataset

# %%
for mode in PartitionedDataset.mode_list:
    PartitionedDataset(counts={'train': 6000, "val": 2000, "test": 2000}, mode=mode, flags=[True,False,False]).generate()
# Out:
# Generating dataset of class:  position_non_aligned_scale
# itteration:  1000
# labels:  1000
# itteration:  2000
# labels:  2000
# itteration:  3000
# labels:  3000
# itteration:  4000
# labels:  4000
# itteration:  5000
# labels:  5000
# itteration:  6000
# itteration:  7000
# labels:  6000
# Finished Generating:  train
# itteration:  8000
# labels:  7000
# itteration:  9000
# labels:  8000
# Finished Generating:  val
# itteration:  10000
# itteration:  11000
# labels:  9000
# itteration:  12000
# itteration:  13000
# labels:  10000
# Finished Generating:  test
# Evaluation time  0:02:25.773253
# Generating dataset of class:  position_common_scale
# itteration:  1000
# labels:  1000
# itteration:  2000
# labels:  2000
# itteration:  3000
# labels:  3000
# itteration:  4000
# labels:  4000
# itteration:  5000
# labels:  5000
# itteration:  6000
# itteration:  7000
# labels:  6000
# Finished Generating:  train
# itteration:  8000
# labels:  7000
# itteration:  9000
# ...

# %%
PartitionedDataset(counts={'train': 6000, "val": 2000, "test": 2000}, mode='length', flags=[True,False,False]).generate()
# Out:
# Generating dataset of class:  length
# itteration:  1000
# labels:  1000
# itteration:  2000
# labels:  2000
# itteration:  3000
# labels:  3000
# itteration:  4000
# labels:  4000
# itteration:  5000
# labels:  5000
# itteration:  6000
# labels:  6000
# Finished Generating:  train
# itteration:  7000
# labels:  7000
# itteration:  8000
# labels:  8000
# Finished Generating:  val
# itteration:  9000
# labels:  9000
# itteration:  10000
# labels:  10000
# Finished Generating:  test
# Evaluation time  0:00:22.502398
