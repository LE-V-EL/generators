# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from datasets import PartitionedDataset 
import matplotlib.pyplot as pylab
import pickle
import pprint

matplotlib.rcParams['figure.figsize'] = [20, 10]

folder = "output/newer/"

# %%
with open(folder + "train_0.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "train_1.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "train_2.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "train_3.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "train_4.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "train_5.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "val_0.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "val_1.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "test_0.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)

# %%
with open(folder + "test_1.p", "rb") as file:
    data = pickle.load(file)
    pyplot.bar(range(len(data.label_distribution)),data.label_distribution)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-50-7c08d09d414d> in <module>
#       1 with open(folder + "test_1.p", "rb") as file:
# ----> 2     data = pickle.load(file)
#       3     pyplot.bar(range(len(data.label_distribution)),data.label_distribution)
#
# EOFError: Ran out of input

# %%
with open("output/newer/" + "test_0.p", "rb") as file:
    data = pickle.load(file)
    pprint.pprint(data.label_distribution)
    print(len(data.label_distribution))
# Out:
# [493,
#  459,
#  412,
#  422,
#  456,
#  447,
#  459,
#  435,
#  467,
#  462,
#  480,
#  452,
#  442,
#  432,
#  431,
#  432,
#  435,
#  453,
#  421,
#  442,
#  456,
#  423,
#  441,
#  432,
#  472,
#  437,
#  451,
#  436,
#  457,
#  429,
#  457,
#  430,
#  467,
#  470,
#  439,
#  446,
#  467,
#  479,
#  459,
#  456,
#  442,
#  452,
#  470,
#  415,
#  429,
#  447,
#  483,
#  431,
#  446,
#  450,
#  431,
#  472,
#  433,
#  420,
#  460,
#  452,
#  461,
#  477,
#  474,
#  460,
#  470,
#  443,
#  457,
#  459,
#  446,
#  476,
#  478,
#  428,
#  442,
#  461,
#  437,
#  455,
#  445,
#  467,
#  436,
#  440,
#  432,
#  473,
#  447,
#  449,
#  429,
#  449,
#  416,
#  425,
#  463,
#  442,
#  428,
#  479,
#  487]
# 89
